# %% [markdown]
# ### Import the required libraries

# %%
import pandas as pd
import numpy as np
import censusdata

# %% [markdown]
# ### Get the variables that represents median income by race

# %% [markdown]
# Search for variables on median

# %%
search_criteria = "median family income"
income_variables = censusdata.search('acs5', 2018,'concept', search_criteria)
income_variables[0:2]
# Out:
# [('B10010_001E',
#   'MEDIAN FAMILY INCOME FOR FAMILIES WITH GRANDPARENT HOUSEHOLDERS AND/OR SPOUSES LIVING WITH OWN GRANDCHILDREN UNDER 18 YEARS BY RESPONSIBILITY FOR OWN GRANDCHILDREN AND PRESENCE OF PARENT OF GRANDCHILDREN',
#   'Estimate!!Median family income in the past 12 months--!!Total'),
#  ('B10010_002E',
#   'MEDIAN FAMILY INCOME FOR FAMILIES WITH GRANDPARENT HOUSEHOLDERS AND/OR SPOUSES LIVING WITH OWN GRANDCHILDREN UNDER 18 YEARS BY RESPONSIBILITY FOR OWN GRANDCHILDREN AND PRESENCE OF PARENT OF GRANDCHILDREN',
#   'Estimate!!Median family income in the past 12 months--!!Grandparent householder and/or spouse responsible for grandchildren under 18 years (dollars)')]

# %% [markdown]
# Converts the list of tuples to a pandas data frame

# %%
dfIV = pd.DataFrame(income_variables, columns=["Variable","Concepts","Labels"])
dfIV.head()
# Out:
#        Variable                                           Concepts  \
# 0   B10010_001E  MEDIAN FAMILY INCOME FOR FAMILIES WITH GRANDPA...
# 1   B10010_002E  MEDIAN FAMILY INCOME FOR FAMILIES WITH GRANDPA...
# 2   B10010_003E  MEDIAN FAMILY INCOME FOR FAMILIES WITH GRANDPA...
# 3  B19113A_001E  MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN...
# 4  B19113B_001E  MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN...
#
#                                               Labels
# 0  Estimate!!Median family income in the past 12 ...
# 1  Estimate!!Median family income in the past 12 ...
# 2  Estimate!!Median family income in the past 12 ...
# 3  Estimate!!Median family income in the past 12 ...
# 4  Estimate!!Median family income in the past 12 ...

# %% [markdown]
# Subset the data frame to exclude the row in the ***Variable*** field that is equal to "GEO_ID". Then displays using some style properties.

# %%
dfIV = dfIV[dfIV["Variable"] != "GEO_ID"]
dfIV.style.set_properties(subset=['Concepts'], **{'width-min': '300px'})
# Out:
# <style  type="text/css" >
# #T_28066462_e31d_11ea_9229_00224845bb7frow0_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow1_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow2_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow3_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow4_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow5_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow6_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow7_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow8_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow9_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow10_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow11_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow12_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow13_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow14_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow15_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow16_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow17_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow18_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow19_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow20_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow21_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow22_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow23_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow24_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow25_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow26_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow27_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow28_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow29_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow30_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow31_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow32_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow33_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow34_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow35_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow36_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow37_col1,#T_28066462_e31d_11ea_9229_00224845bb7frow38_col1{
#             width-min:  300px;
#         }</style><table id="T_28066462_e31d_11ea_9229_00224845bb7f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Variable</th>        <th class="col_heading level0 col1" >Concepts</th>        <th class="col_heading level0 col2" >Labels</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_28066462_e31d_11ea_9229_00224845bb7flevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_28066462_e31d_11ea_9229_00224845bb7frow0_col0" class="data row0 col0" >B10010_001E</td>
#                         <td id="T_28066462_e31d_11ea_9229_00224845bb7frow0_col1" class="data row0 col1" >MEDIAN FAMILY INCOME FOR FAMILIES WITH GRANDPARENT HOUSEHOLDERS AND/OR SPOUSES LIVING WITH OWN GRANDCHILDREN UNDER 18 YEARS BY RESPONSIBILITY FOR OWN GRANDCHILDREN AND PRESENCE OF PARENT OF GRANDCHILDREN</td>
#                         <td id="T_28066462_e31d_11ea_9229_00224845bb7frow0_col2" class="data row0 col2" >Estimate!!Median family income in the past 12 months--!!Total</td>
#             </tr>
#             <tr>
#                         <th id="T_28066462_e31d_11ea_9229_00224845bb7flevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_28066462_e31d_11ea_9229_00224845bb7frow1_col0" class="data row1 col0" >B10010_002E</td>
#                         <td id="T_28066462_e31d_11ea_9229_00224845bb7frow1_col1" class="data row1 col1" >MEDIAN FAMILY INCOME FOR FAMILIES WITH GRANDPARENT HOUSEHOLDERS AND/OR SPOUSES LIVING WITH OWN GRANDCHILDREN UNDER 18 YEARS BY RESPONSIBILITY FOR OWN GRANDCHILDREN AND PRESENCE OF PARENT OF GRANDCHILDREN</td>
#                         <td id="T_28066462_e31d_11ea_9229_00224845bb7frow1_col2" class="data row1 col2" >Estimate!!Median family income in the past 12 months--!!Grandparent householder and/or spouse responsible for grandchildren under 18 years (dollars)</td>
#             </tr>
#             <tr>
#                         <th id="T_28066462_e31d_11ea_9229_00224845bb7flevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_28066462_e31d_11ea_9229_00224845bb7frow2_col0" class="data row2 col0" >B10010_003E</td>
#                         <td id="T_28066462_e31d_11ea_9229_00224845bb7frow2_col1" class="data row2 col1" >MEDIAN FAMILY INCOME FOR FAMILIES WITH GRANDPARENT HOUSEHOLDERS AND/OR SPOUSES LIVING WITH OWN GRANDCHILDREN UNDER 18 YEARS BY RESPONSIBILITY FOR OWN GRANDCHILDREN AND PRESENCE OF PARENT OF GRANDCHILDREN</td>
#                         <td id="T_28066462_e31d_11ea_9229_00224845bb7frow2_col2" class="data row2 col2" >Estimate!!Median family income in the past 12 months--!!Grandparent householder and/or spouse responsible for grandchildren under 18 years and no parent present (dollars)</td>
#             </tr>
#             <tr>
#                         <th id="T_28066462_e31d_11ea_9229_00224845bb7flevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_28066462_e31d_11ea_9229_00224845bb7frow3_col0" class="data row3 col0" >B19113A_001E</td>
#                         <td id="T_28066462_e31d_11ea_9229_00224845bb7frow3_col1" class="data row3 col1" >MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE HOUSEHOLDER)</td>
#                         <td id="T_28066462_e31d_11ea_9229_00224845bb7frow3_col2" class="data row3 col2" >Estimate!!Median family income in the past 12 months (in 2018 inflation-adjusted dollars)</td>
#             </tr>
#             <tr>
#                         <th id="T_28066462_e31d_11ea_9229_00224845bb7flevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_28066462_e31d_11ea_9229_00224845bb7frow4_col0" class="data row4 col0" >B19113B_001E</td>
#                         <td id="T_28066462_e31d_11ea_9229_00224845bb7frow4_col1" class="data row4 col1" >MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS) (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)</td>
#                         <td id="T_28066462_e31d_11ea_9229_00224845bb7frow4_col2" class="data row4 col2" >Estimate!!Median family income in the past 12 months (in 2018 inflation-adjusted dollars)</td>
#             </tr>
#             <tr>
#                         <th id="T_28066462_e31d_11ea_9229_00224845bb7flevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_28066462_e31d_11ea_9229_00224845bb7frow5_col0" class="data row5 col0" >B19113C_001E</td>
#                         <td id="T_28066462_e31d_11ea_9229_00224845bb7frow5_col1" class="data row5 col1" >MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS) (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER)</td>
#                         <td id="T_28066462_e31d_11ea_9229_00224845bb7frow5_col2" class="data row5 col2" >Estimate!!Median family income in the past 12 months (in 2018 inflation-adjusted dollars)</td>
#             </tr>
#             <tr>
#                         <th id="T_28066462_e31d_11ea_9229_00224845bb7flevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_28066462_e31d_11ea_9229_00224845bb7frow6_col0" class="data row6 col0" >B19113D_001E</td>
#                         <td id="T_28066462_e31d_11ea_9229_00224845bb7frow6_col1" class="data row6 col1" >MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS) (ASIAN ALONE HOUSEHOLDER)</td>
#                         <td id="T_28066462_e31d_11ea_9229_00224845bb7frow6_col2" class="data row6 col2" >Estimate!!Median family income in the past 12 months (in 2018 inflation-adjusted dollars)</td>
#             </tr>
#             <tr>
#                         <th id="T_28066462_e31d_11ea_9229_00224845bb7flevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_28066462_e31d_11ea_9229_00224845bb7frow7_col0" class="data row7 col0" >B19113E_001E</td>
#                         <td id="T_28066462_e31d_11ea_9229_00224845bb7frow7_col1" clas

# %% [markdown]
# ### Put the variables that represent variables you want to retrieve in a list

# %%
cns_vars = [
    "B19113_001E","B19113A_001E","B19113B_001E","B19113C_001E",
    "B19113D_001E","B19113E_001E","B19113F_001E","B19113G_001E",
    "B19113H_001E","B19113I_001E"
    ]

# %% [markdown]
# ### Define the names you want to use

# %%
new_names = {
    'index':'Geography',"B19113_001E":"ALL","B19113A_001E":"WHITE",
    "B19113B_001E":"BLACK","B19113C_001E":"INDIAN","B19113D_001E":"ASIAN",
    "B19113E_001E":"PACIFIC","B19113F_001E":"OTHER","B19113G_001E":"MIX",
    "B19113H_001E":"JUST WHITE","B19113I_001E":"HISPANIC"
}

# %% [markdown]
# ### Define the geographies you want data on

# %%
geographies = [('us', '*')]

# %% [markdown]
# ### Fetch the data from the census api using the 5 year estimates for 2018

# %%
MEDINC_BY_US_BY_RACE = censusdata.download(
    'acs5', 2018, censusdata.censusgeo(geographies), 
    cns_vars)

# %% [markdown]
# ### Reest the index for the MEDINC_BY_STATE_BY_RACE data frame

# %%
MEDINC_BY_US_BY_RACE = MEDINC_BY_US_BY_RACE.reset_index()

# %% [markdown]
# ### Rename the columns with more meaningful names

# %%
MEDINC_BY_US_BY_RACE = MEDINC_BY_US_BY_RACE.rename(columns=new_names)
MEDINC_BY_US_BY_RACE.head()
# Out:
#                                  Geography    ALL  WHITE  BLACK  INDIAN  \
# 0  United States: Summary level: 010, us:1  73965  78986  49270   49451
#
#    ASIAN  PACIFIC  OTHER    MIX  JUST WHITE  HISPANIC
# 0  96439    65618  48058  66304       83246     51800

# %% [markdown]
# ### Create a function to get the location name

# %%
def getLocation(row):
    return row["Geography"].name

# %% [markdown]
# ### Sets the location field based on thee getLocation() field. Sets the "Place" field to the "Location" field

# %%
MEDINC_BY_US_BY_RACE["Location"] = MEDINC_BY_US_BY_RACE.apply(lambda row:  getLocation(row),axis=1)
MEDINC_BY_US_BY_RACE["Place"] = MEDINC_BY_US_BY_RACE["Location"]

# %%
MEDINC_BY_US_BY_RACE.head()
# Out:
#                                  Geography    ALL  WHITE  BLACK  INDIAN  \
# 0  United States: Summary level: 010, us:1  73965  78986  49270   49451
#
#    ASIAN  PACIFIC  OTHER    MIX  JUST WHITE  HISPANIC       Location  \
# 0  96439    65618  48058  66304       83246     51800  United States
#
#            Place
# 0  United States

# %% [markdown]
# ### Sets the Query field

# %%
MEDINC_BY_US_BY_RACE["Query Type"] = "Country"

# %% [markdown]
# ### Get the median income data at the ***state*** level

# %%
# Define the geographies you want data on
geographies = [('state', '*')]

# Fetch the data from the census api using the 5 year estimates for 
# 2018 
MEDINC_BY_STATE_BY_RACE = censusdata.download(
    'acs5', 2018, censusdata.censusgeo(geographies), 
    cns_vars)

# Reest the index for the MEDINC_BY_STATE_BY_RACE data frame
MEDINC_BY_STATE_BY_RACE = MEDINC_BY_STATE_BY_RACE.reset_index()

# Rename the columns with more meaningful names
MEDINC_BY_STATE_BY_RACE = MEDINC_BY_STATE_BY_RACE.rename(columns=new_names)

# Create a function to get the location name
def getLocation(row):
    return row["Geography"].name

# Sets the location field based on thee getLocation() field. Sets the "Place" field to the "Location" field
MEDINC_BY_STATE_BY_RACE["Location"] = MEDINC_BY_STATE_BY_RACE.apply(lambda row:  getLocation(row),axis=1)
MEDINC_BY_STATE_BY_RACE["Place"] = MEDINC_BY_STATE_BY_RACE["Location"]

# Sets the Query field
MEDINC_BY_STATE_BY_RACE["Query Type"] = "State"

# %%
MEDINC_BY_STATE_BY_RACE
# Out:
#                                             Geography     ALL   WHITE  BLACK  \
# 0             Minnesota: Summary level: 040, state:27   86204   90511  41891
# 1           Mississippi: Summary level: 040, state:28   54933   67910  36083
# 2              Missouri: Summary level: 040, state:29   67612   70959  43905
# 3               Montana: Summary level: 040, state:30   68139   70097  47050
# 4              Nebraska: Summary level: 040, state:31   75123   77802  42277
# 5                Nevada: Summary level: 040, state:32   68700   74562  48754
# 6         New Hampshire: Summary level: 040, state:33   91245   91877  62139
# 7            New Jersey: Summary level: 040, state:34   98047  106497  63387
# 8            New Mexico: Summary level: 040, state:35   59175   63383  50871
# 9              New York: Summary level: 040, state:36   80419   92553  58406
# 10       North Carolina: Summary level: 040, state:37   65097   72691  45417
# 11         North Dakota: Summary level: 040, state:38   83272   86908  46586
# 12                 Ohio: Summary level: 040, state:39   69837   74104  39759
# 13             Oklahoma: Summary level: 040, state:40   63574   67724  41824
# 14               Oregon: Summary level: 040, state:41   72823   74271  47340
# 15         Pennsylvania: Summary level: 040, state:42   75477   79664  45771
# 16         Rhode Island: Summary level: 040, state:44   81822   88569  49980
# 17       South Carolina: Summary level: 040, state:45   63437   72703  41548
# 18         South Dakota: Summary level: 040, state:46   72706   76774  35199
# 19            Tennessee: Summary level: 040, state:47   63096   66860  44495
# 20                Texas: Summary level: 040, state:48   70423   73894  54788
# 21                 Utah: Summary level: 040, state:49   77732   80294  50019
# 22              Vermont: Summary level: 040, state:50   77193   77912  44230
# 23             Virginia: Summary level: 040, state:51   86628   93474  60309
# 24        West Virginia: Summary level: 040, state:54   57598   58199  42885
# 25           Washington: Summary level: 040, state:53   84182   86787  59863
# 26            Wisconsin: Summary level: 040, state:55   75313   79044  35519
# 27              Wyoming: Summary level: 040, state:56   77480   78721  57188
# 28          Puerto Rico: Summary level: 040, state:72   24391   25333  24158
# 29              Alabama: Summary level: 040, state:01   62030   70093  41170
# 30               Alaska: Summary level: 040, state:02   90284  101189  58807
# 31              Arizona: Summary level: 040, state:04   66988   70427  54931
# 32             Arkansas: Summary level: 040, state:05   57065   61924  36856
# 33           California: Summary level: 040, state:06   81416   86689  61189
# 34             Colorado: Summary level: 040, state:08   84540   87980  58472
# 35          Connecticut: Summary level: 040, state:09   97310  106622  57666
# 36             Delaware: Summary level: 040, state:10   79814   84132  60869
# 37  District of Columbia: Summary level: 040, stat...  105029  201695  54778
# 38              Florida: Summary level: 040, state:12   64312   68699  46345
# 39              Georgia: Summary level: 040, state:13   67405   77080  49807
# 40                Idaho: Summary level: 040, state:16   64723   65823  50060
# 41               Hawaii: Summary level: 040, state:15   90935   93138  77404
# 42             Illinois: Summary level: 040, state:17   79747   86829  47112
# 43              Indiana: Summary level: 040, state:18   68054   71354  41059
# 44                 Iowa: Summary level: 040, state:19   74794   76740  32283
# 45               Kansas: Summary level: 040, state:20   73222   75702  47935
# 46             Kentucky: Summary level: 040, state:21   61059   63114  41284
# 47            Louisiana: Summary level: 040, state:22   61785   74801  36583
# 48                Maine: Summary level: 040, state:23   70370   71121  41024
# 49             Maryland: Summary level: 040, state:24   99403  110812  78854
# 50        Massachusetts: Summary level: 040, state:25   98625  105352  59676
# 51             Michigan: Summary level: 040, state:26   69691   74045  41277
#
#     INDIAN   ASIAN    PACIFIC  OTHER     MIX  JUST WHITE  HISPANIC  \
# 0    41988   82767      73036  44056   64187       91432     49426
# 1    40196   69004      50160  41863   48971       68466     44566
# 2    55236   88419      53594  39608   53025       71390     50307
# 3    40959   90125      28469  62900   53877       70522     52583
# 4    43295   68654      52813  47671   51224       80477     48565
# 5    49846   74479      66710  47477   65483       80394     52317
# 6    52099   95765      55673  61875   78702       92543     59101
# 7    65906  127067      48563  48587   81274      114801     56910
# 8    37741   73728      61850  42407   59913       77590     47703
# 9    50108   77938      60295  43104   63412       96047     50984
# 10   44879   90516      52241  36700   54472       74876     39917
# 11   38516   75438 -666666666  50910   63984       87419     52059
# 12   43017   89220      64212  42075   48936       74590     46562
# 13   51915   71301      41745  42476   55946       69590     44977
# 14   49579   89702      64012  51742   59637       76749     49166
# 15   43571   86714      57485  36933   52667       81046     42369
# 16   35796   82051      40788  38260   54562       93137     40624
# 17   49684   71937      37917  39901   57292       73850     43488
# 18   27483   64809      27155  50697   49488       77222     48275
# 19   52419   83722 -666666666  37413   53471       67811     42039
# 20   61664   97701      56920  46700   69877       91936     50113
# 21   48033   80941      66960  48381   65334       82455     52011
# 22   46205   70694 -666666666  57298   62758       78068     61159
# 23   71594  113717      87708  54777   82371       95342     64994
# 24   54821   78566      60545  43324   53977       58205     50987
# 25   51521  104005      66455  48732   74064       89629     53373
# 26   46922   77576      48372  41770   56132       80153     46545
# 27   57667   77986      70592  45659   73433       80484     55097
# 28   24030   26612 -666666666  20388   25164       38226     24292
# 29   59301   76917      56391  33610   55557       70774     40744
# 30   55129   75334      65684  68661   77966      102463     73148
# 31   39677   91212      60224  44420   60378       78239     47892
# 32   42691   76751      36174  38261   50660       63011     40891
# 33   59029  103269      77802  53005   82418      104867     56114
# 34   58886   85839      71571  52239   75496       95045     54449
# 35   53821  105632     198448  41793   69568      112246     49380
# 36   61250  109020      53587  53665   62188       86336     54939
# 37   55750  150888 -666666666  55285  135734      208622     73053
# 38   53714   79042      61112  46932   59740       74726     50821
# 39   44465   84559      43010  42393   62567       79762     47298
# 40   47222   64515      66848  46060   59576       67580     47240
# 41   52857   98701      65961  65962   88548       96103     70331
# 42   61023  100828      84565  51936   66846       91017     55955
# 43   49567   78822      53352  43250   51092       72219     48314
# 44   42961   71831      35988  48989   47648       77736     48798
# 45   56006   83620      52928  48150   57302       78379     48117
# 46   38026   69448      53000  35485   49807       63450     43469
# 47   52406   70976      64844  39841   57600       76018     48100
# 48   38060   74500      88750  68750   45544       71175     63664
# 49   90662  115798      94853  59588   92954      113218     68882
# 50   43028  107276      78684  43503   66172      108918     44374
# 51   51186  100163      62292  45404   53518       74736     50182
#
#                 Location                 Place Query Type
# 0              Minnesota             Minnesota      State
# 1            Mississippi           Mississippi      State
# 2               Missouri              Missouri      State
# 3                Montana               Montana      State
# 4               Nebraska              Nebraska      State
# 5                 Nevada                Nevada      State
# 6          New Hampshire         New Hampshire      State
# 7             New Jersey            New Jersey      State
# 8             New Mexico            New Mexico      State
# 9               New York              New York      State
# 10        North Carolina        North Carolina      State
# 11          North Dakota          North Dakota      State
# 12                  Ohio                  Ohio      State
# 13              Oklahoma              Oklahoma      State
# 14                Oregon                Oregon      State
# 15          Pennsylvania          Pennsylvania      State
# 16          Rhode Island          Rhode Island      State
# 17        South Carolina        South Carolina      State
# 18          South Dakota          South Dakota      State
# 19             Tennessee             Tennessee      State
# 20                 Texas                 Texas      State
# 21                  Utah                  Utah      State
# 22               Vermont               Vermont      State
# 23              Virginia              Virginia      State
# 24         West Virginia         West Virginia      State
# 25            Washington            Washington      State
# 26             Wisconsin             Wisconsin      State
# 27               Wyoming               Wyoming      State
# 28           Puerto Rico           Puerto Rico      State
# 29               Alabama               Alabama      State
# 30                Alaska                Alaska      State
# 31               Arizona               Arizona      State
# 32              Arkansas              Arkansas      State
# 33            California            California      State
# 34              Colorado              Colorado      State
# 35           Connecticut           Connecticut      State
# 36              Delaware              Delaware      State
# 37  District of Columbia  District of Columbia      State
# 38               Florida               Florida      State
# 39               Georgia               Georgia      State
# 40                 Idaho                 Idaho      State
# 41                Hawaii                Hawaii      State
# 42              Illinois              Illinois      State
# 43               Indiana               Indiana      State
# 44                  Iowa                  Iowa      State
# 45                Kansas                Kansas      State
# 46              Kentucky              Kentucky      State
# 47             Louisiana             Louisiana      State
# 48                 Maine                 Maine      State
# 49              Maryland              Maryland      State
# 50         Massachusetts         Massachusetts      State
# 51              Michigan              Michigan      State

# %% [markdown]
# ### Get the median income data at the ***place*** level

# %%
# Define a new set of geographies based on places
geographies = [('state', '*'),('place','*')]

# Fetch the data from the census api
MEDINC_BY_STATE_BY_PLACE_BY_RACE = censusdata.download(
    'acs5', 2018, censusdata.censusgeo(geographies), 
    cns_vars)

# Reset your index
MEDINC_BY_STATE_BY_PLACE_BY_RACE = MEDINC_BY_STATE_BY_PLACE_BY_RACE.reset_index()

# Give the columns more meaningful names
MEDINC_BY_STATE_BY_PLACE_BY_RACE = MEDINC_BY_STATE_BY_PLACE_BY_RACE.rename(columns=new_names)

# Sets the "Place" field using the getLocation() function
MEDINC_BY_STATE_BY_PLACE_BY_RACE["Place"] = MEDINC_BY_STATE_BY_PLACE_BY_RACE.apply(lambda row:  getLocation(row),axis=1)

# Create a function to get the State out of the "Place" field and uses it to set the "Location" field
def getState(place):
    return place.split(",",1)[1]
MEDINC_BY_STATE_BY_PLACE_BY_RACE["Location"] = MEDINC_BY_STATE_BY_PLACE_BY_RACE["Place"].apply(lambda place: getState(place))

# Sets the Query field
MEDINC_BY_STATE_BY_PLACE_BY_RACE["Query Type"] = "Place"

# %%
# Get the shape of the data frame
MEDINC_BY_STATE_BY_PLACE_BY_RACE.shape
# Out:
# (29573, 14)

# %%
MEDINC_BY_STATE_BY_PLACE_BY_RACE.head()
# Out:
#                                            Geography      ALL        WHITE  \
# 0  Abanda CDP, Alabama: Summary level: 160, state...  41346.0 -666666666.0
# 1  Abbeville city, Alabama: Summary level: 160, s...  53036.0      71563.0
# 2  Adamsville city, Alabama: Summary level: 160, ...  52846.0      60236.0
# 3  Addison town, Alabama: Summary level: 160, sta...  59167.0      59167.0
# 4  Akron town, Alabama: Summary level: 160, state...  36000.0      60375.0
#
#          BLACK       INDIAN        ASIAN      PACIFIC        OTHER  \
# 0 -666666666.0 -666666666.0 -666666666.0 -666666666.0 -666666666.0
# 1      35000.0 -666666666.0 -666666666.0 -666666666.0 -666666666.0
# 2      51696.0 -666666666.0 -666666666.0 -666666666.0 -666666666.0
# 3 -666666666.0 -666666666.0 -666666666.0 -666666666.0 -666666666.0
# 4      24583.0 -666666666.0 -666666666.0 -666666666.0 -666666666.0
#
#            MIX   JUST WHITE     HISPANIC                     Place  Location  \
# 0 -666666666.0 -666666666.0 -666666666.0       Abanda CDP, Alabama   Alabama
# 1 -666666666.0      71563.0 -666666666.0   Abbeville city, Alabama   Alabama
# 2 -666666666.0      60236.0 -666666666.0  Adamsville city, Alabama   Alabama
# 3 -666666666.0      59167.0 -666666666.0     Addison town, Alabama   Alabama
# 4 -666666666.0      60375.0 -666666666.0       Akron town, Alabama   Alabama
#
#   Query Type
# 0      Place
# 1      Place
# 2      Place
# 3      Place
# 4      Place

# %% [markdown]
# ### Combines the contents from the MEDINC_BY_STATE_BY_PLACE_BY_RACE data frame and MEDINC_BY_STATE_BY_RACE data frame into one data frame.

# %%
MEDINC_BY_LOCATION_BY_PLACE_BY_RACE = MEDINC_BY_US_BY_RACE

MEDINC_BY_LOCATION_BY_PLACE_BY_RACE = \
    MEDINC_BY_LOCATION_BY_PLACE_BY_RACE.append(MEDINC_BY_STATE_BY_RACE, ignore_index = True)

MEDINC_BY_LOCATION_BY_PLACE_BY_RACE = \
    MEDINC_BY_LOCATION_BY_PLACE_BY_RACE.append(MEDINC_BY_STATE_BY_PLACE_BY_RACE, ignore_index = True)
MEDINC_BY_LOCATION_BY_PLACE_BY_RACE.head()
# Out:
#                                    Geography      ALL    WHITE    BLACK  \
# 0    United States: Summary level: 010, us:1  73965.0  78986.0  49270.0
# 1    Minnesota: Summary level: 040, state:27  86204.0  90511.0  41891.0
# 2  Mississippi: Summary level: 040, state:28  54933.0  67910.0  36083.0
# 3     Missouri: Summary level: 040, state:29  67612.0  70959.0  43905.0
# 4      Montana: Summary level: 040, state:30  68139.0  70097.0  47050.0
#
#     INDIAN    ASIAN  PACIFIC    OTHER      MIX  JUST WHITE  HISPANIC  \
# 0  49451.0  96439.0  65618.0  48058.0  66304.0     83246.0   51800.0
# 1  41988.0  82767.0  73036.0  44056.0  64187.0     91432.0   49426.0
# 2  40196.0  69004.0  50160.0  41863.0  48971.0     68466.0   44566.0
# 3  55236.0  88419.0  53594.0  39608.0  53025.0     71390.0   50307.0
# 4  40959.0  90125.0  28469.0  62900.0  53877.0     70522.0   52583.0
#
#         Location          Place Query Type
# 0  United States  United States    Country
# 1      Minnesota      Minnesota      State
# 2    Mississippi    Mississippi      State
# 3       Missouri       Missouri      State
# 4        Montana        Montana      State

# %% [markdown]
# ### Replaces -666666666 with NaN

# %%
MEDINC_BY_LOCATION_BY_PLACE_BY_RACE = MEDINC_BY_LOCATION_BY_PLACE_BY_RACE.replace(-666666666, np.nan)
MEDINC_BY_LOCATION_BY_PLACE_BY_RACE.head(100)
# Out:
#                                             Geography      ALL    WHITE  \
# 0             United States: Summary level: 010, us:1  73965.0  78986.0
# 1             Minnesota: Summary level: 040, state:27  86204.0  90511.0
# 2           Mississippi: Summary level: 040, state:28  54933.0  67910.0
# 3              Missouri: Summary level: 040, state:29  67612.0  70959.0
# 4               Montana: Summary level: 040, state:30  68139.0  70097.0
# ..                                                ...      ...      ...
# 95  Bellamy CDP, Alabama: Summary level: 160, stat...  29205.0      NaN
# 96  Belle Fontaine CDP, Alabama: Summary level: 16...      NaN      NaN
# 97  Benton town, Alabama: Summary level: 160, stat...  64688.0  64688.0
# 98  Berry town, Alabama: Summary level: 160, state...  56250.0  56806.0
# 99  Bessemer city, Alabama: Summary level: 160, st...  40601.0  48520.0
#
#       BLACK   INDIAN    ASIAN  PACIFIC    OTHER      MIX  JUST WHITE  \
# 0   49270.0  49451.0  96439.0  65618.0  48058.0  66304.0     83246.0
# 1   41891.0  41988.0  82767.0  73036.0  44056.0  64187.0     91432.0
# 2   36083.0  40196.0  69004.0  50160.0  41863.0  48971.0     68466.0
# 3   43905.0  55236.0  88419.0  53594.0  39608.0  53025.0     71390.0
# 4   47050.0  40959.0  90125.0  28469.0  62900.0  53877.0     70522.0
# ..      ...      ...      ...      ...      ...      ...         ...
# 95  37793.0      NaN      NaN      NaN      NaN      NaN         NaN
# 96      NaN      NaN      NaN      NaN      NaN      NaN         NaN
# 97      NaN      NaN      NaN      NaN      NaN      NaN     64688.0
# 98      NaN      NaN      NaN      NaN      NaN      NaN     56806.0
# 99  36855.0      NaN      NaN      NaN      NaN  55444.0     49195.0
#
#     HISPANIC       Location                        Place Query Type
# 0    51800.0  United States                United States    Country
# 1    49426.0      Minnesota                    Minnesota      State
# 2    44566.0    Mississippi                  Mississippi      State
# 3    50307.0       Missouri                     Missouri      State
# 4    52583.0        Montana                      Montana      State
# ..       ...            ...                          ...        ...
# 95       NaN        Alabama         Bellamy CDP, Alabama      Place
# 96       NaN        Alabama  Belle Fontaine CDP, Alabama      Place
# 97       NaN        Alabama         Benton town, Alabama      Place
# 98       NaN        Alabama          Berry town, Alabama      Place
# 99       NaN        Alabama       Bessemer city, Alabama      Place
#
# [100 rows x 14 columns]

# %% [markdown]
# ### Choose the columns that you want to keep in the order you want them

# %%
colnames = ['Query Type', 'Location', 'Place', 'ALL', 'WHITE', 'BLACK', 'INDIAN', 'ASIAN', 'PACIFIC','OTHER', 'MIX', 'JUST WHITE', 'HISPANIC']
MEDINC_BY_LOCATION_BY_PLACE_BY_RACE = MEDINC_BY_LOCATION_BY_PLACE_BY_RACE.loc[:,colnames]
MEDINC_BY_LOCATION_BY_PLACE_BY_RACE.head()
# Out:
#   Query Type       Location          Place      ALL    WHITE    BLACK  \
# 0    Country  United States  United States  73965.0  78986.0  49270.0
# 1      State      Minnesota      Minnesota  86204.0  90511.0  41891.0
# 2      State    Mississippi    Mississippi  54933.0  67910.0  36083.0
# 3      State       Missouri       Missouri  67612.0  70959.0  43905.0
# 4      State        Montana        Montana  68139.0  70097.0  47050.0
#
#     INDIAN    ASIAN  PACIFIC    OTHER      MIX  JUST WHITE  HISPANIC
# 0  49451.0  96439.0  65618.0  48058.0  66304.0     83246.0   51800.0
# 1  41988.0  82767.0  73036.0  44056.0  64187.0     91432.0   49426.0
# 2  40196.0  69004.0  50160.0  41863.0  48971.0     68466.0   44566.0
# 3  55236.0  88419.0  53594.0  39608.0  53025.0     71390.0   50307.0
# 4  40959.0  90125.0  28469.0  62900.0  53877.0     70522.0   52583.0

# %% [markdown]
# ### Creates a boolean series that returns true if all of the race fields are null and returns False otherwise. This series will be used to subset the MEDINC_BY_LOCATION_BY_PLACE_BY_RACE by removing all records where the "race" fields are all nulls.

# %%
logic = \
    ~(
        MEDINC_BY_LOCATION_BY_PLACE_BY_RACE["ALL"] .isnull() & \
        MEDINC_BY_LOCATION_BY_PLACE_BY_RACE["WHITE"] .isnull() & \
        MEDINC_BY_LOCATION_BY_PLACE_BY_RACE["BLACK"] .isnull() & \
        MEDINC_BY_LOCATION_BY_PLACE_BY_RACE["INDIAN"] .isnull() & \
        MEDINC_BY_LOCATION_BY_PLACE_BY_RACE["ASIAN"] .isnull() & \
        MEDINC_BY_LOCATION_BY_PLACE_BY_RACE["PACIFIC"] .isnull() & \
        MEDINC_BY_LOCATION_BY_PLACE_BY_RACE["OTHER"] .isnull() & \
        MEDINC_BY_LOCATION_BY_PLACE_BY_RACE["MIX"] .isnull() & \
        MEDINC_BY_LOCATION_BY_PLACE_BY_RACE["JUST WHITE"] .isnull() & \
        MEDINC_BY_LOCATION_BY_PLACE_BY_RACE["HISPANIC"] .isnull()
    )

# %%
logic
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 29621    False
# 29622    False
# 29623    False
# 29624    False
# 29625    False
# Length: 29626, dtype: bool

# %%
MEDINC_BY_LOCATION_BY_PLACE_BY_RACE.shape

# %%
MEDINC_BY_LOCATION_BY_PLACE_BY_RACE = MEDINC_BY_LOCATION_BY_PLACE_BY_RACE[logic]

# %%
MEDINC_BY_LOCATION_BY_PLACE_BY_RACE.shape
# Out:
# (27287, 13)

# %%
MEDINC_BY_LOCATION_BY_PLACE_BY_RACE.head()
# Out:
#   Query Type       Location          Place      ALL    WHITE    BLACK  \
# 0    Country  United States  United States  73965.0  78986.0  49270.0
# 1      State      Minnesota      Minnesota  86204.0  90511.0  41891.0
# 2      State    Mississippi    Mississippi  54933.0  67910.0  36083.0
# 3      State       Missouri       Missouri  67612.0  70959.0  43905.0
# 4      State        Montana        Montana  68139.0  70097.0  47050.0
#
#     INDIAN    ASIAN  PACIFIC    OTHER      MIX  JUST WHITE  HISPANIC
# 0  49451.0  96439.0  65618.0  48058.0  66304.0     83246.0   51800.0
# 1  41988.0  82767.0  73036.0  44056.0  64187.0     91432.0   49426.0
# 2  40196.0  69004.0  50160.0  41863.0  48971.0     68466.0   44566.0
# 3  55236.0  88419.0  53594.0  39608.0  53025.0     71390.0   50307.0
# 4  40959.0  90125.0  28469.0  62900.0  53877.0     70522.0   52583.0

# %% [markdown]
# ### Python resources

# %% [markdown]
# - Python for Informatics: http://www.py4inf.com/
# - Link to Data School YouTube channel
# - Link to the CensusData github site
